# %%
import sys
import numpy as np
from pycbc.detector import Detector
import bilby
import json
import dill
from pycbc.waveform import get_td_waveform
import bilby
# from gwpy.timeseries import TimeSeries
from Relative_22_row_new import *
from scipy.linalg import toeplitz, inv, circulant
from scipy.fft import fft, ifft
import h5py
from scipy.linalg import toeplitz, inv
import scipy.signal as sig
from pycbc.detector import Detector
import dill
from scipy.signal import welch
from gwpy.timeseries import TimeSeries
from gwosc.datasets import event_gps
from scipy.signal.windows import tukey
from pycbc.filter import highpass, lowpass
from pycbc.types import TimeSeries
import matplotlib.pyplot as plt
from bilby.gw.conversion import component_masses_to_chirp_mass, chirp_mass_and_mass_ratio_to_component_masses
logger = bilby.core.utils.logger
# Out:
# /home/neha/miniconda3/envs/LALSuite_edited/lib/python3.12/site-packages/pycbc/types/array.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal as _lal
# /home/neha/local/lalsuite/lib/python3.12/site-packages/lalsimulation/__init__.py

# %%
import numpy as np
import scipy.signal as sig
import scipy.signal.windows as win

def condition_data(time, data, 
                   f_min=None, 
                   f_max=None, 
                   trim=0.0, 
                   digital_filter=True, 
                   remove_mean=True,):

    data = np.asarray(data)
    time = np.asarray(time)

    dt = time[1] - time[0]
    fny = 0.5 / dt

    # --- Filtering ---
    if f_min and not f_max:
        b, a = sig.butter(4, f_min / fny, btype="highpass")
    elif f_max and not f_min:
        b, a = sig.butter(4, f_max / fny, btype="lowpass")
    elif f_min and f_max:
        b, a = sig.butter(4, (f_min / fny, f_max / fny), btype="bandpass")
    else:
        b, a = None, None

    if b is not None:
        data = sig.filtfilt(b, a, data)

    # --- Trimming ---
    N = len(data)
    istart = int(round(trim * N))
    iend = int(round((1 - trim) * N))
    data = data[istart:iend]
    time = time[istart:iend]

    # --- Mean removal ---
    if remove_mean:
        data -= np.mean(data)
        print(np.mean(data))

    return time, data

# %%
outdir = "outdir"
label = "GW190425"

trigger_time = 1240215503.0
detectors = ["L1","V1"]
maximum_frequency = 512
minimum_frequency = 20
duration = 128
post_trigger_duration = 0.1
Time_array = np.arange(-duration+post_trigger_duration,post_trigger_duration,1/4096)
end_time = trigger_time + post_trigger_duration
start_time = end_time - duration
roll_off = 0.4

psd_duration = 1024
psd_start_time = start_time - psd_duration
psd_end_time = start_time

fiducial_parameters = {
    "chi_1": 0.01,
    "chi_2": 0.01,
    "chirp_mass": 1.48655,
    "dec": 0.0,
    "geocent_time": 1240215503.042,
    "luminosity_distance": 150,
    "mass_ratio": 0.8955,
    "phase": 3.0136566567608765,
    "psi": 0.281,
    "ra": 4.2,
    "theta_jn": 0.6,
}
# L1_ifo = bilby.gw.detector.get_empty_interferometer("L1")
# to_L1 = L1_ifo.time_delay_from_geocenter(
#     ra = fiducial_parameters["ra"],
#     dec = fiducial_parameters["dec"],
#     time = fiducial_parameters["geocent_time"]
#     )
# fiducial_parameters["L1_time"] = fiducial_parameters["geocent_time"] + to_L1
# fiducial_parameters.pop("geocent_time")

# %%
def acf_from_psd(psd_data,fs,N):
    delta_t = 1/fs
    rho = 0.5 * np.real(np.fft.irfft(a=psd_data,)) / (delta_t)
    return rho

def inverse_circulant_first_row(c):
    eigenvalues = fft(c)
    if np.any(eigenvalues == 0):
        raise ValueError("The matrix is singular and does not have an inverse.")
    inv_eigenvalues = 1 / eigenvalues
    c_inv_first_row = ifft(inv_eigenvalues).real
    return c_inv_first_row

# %%
Detectors_list = {"V1":Detector("V1"),"L1":Detector("L1")}

# %%
fs = 4096

Data_list = {}
PSD_dict = {}
Noise_dict = {}
# nperseg = 64*fs
psd_alpha = 2 * 0.4 / duration
print(psd_alpha)
tukey_window = tukey(len(Time_array), alpha=psd_alpha)
# tukey_window = tukey(nperseg, alpha=psd_alpha)
C_inv = {}
for det in Detectors_list.keys():
    fname = f"{det}_GWOSC.hdf5"
    with h5py.File(fname, "r") as f:
        data_full = f["strain/Strain"][:]
        dt = f["strain/Strain"].attrs["Xspacing"]
        t_start = f["meta/GPSstart"][()]
        full_duration = f["meta/Duration"][()]
        t_end = t_start + full_duration
        t = np.arange(t_start, t_end, dt)
        idx = np.where((t >= start_time) & (t < end_time))[0]
        
        data_full = TimeSeries(data_full, epoch = start_time, delta_t = dt)
        # data_full = highpass(data_full, minimum_frequency)
        # data_full = lowpass(data_full, maximum_frequency)
        data = data_full[idx]
        Data_list[det] = data
        
        idx2 = np.where((t >= psd_start_time) & (t < psd_end_time))[0]
        noise = data_full[idx2]
        psd = welch(x=noise, fs=4096, window=tukey_window, average="median")
        PSD_dict[det] = psd
# Out:
# 0.00625

# %%
C_inv_row = {}
fs = 4096
Data_list = {}
for det in Detectors_list.keys():
    fname = f"{det}_GWOSC.hdf5"
    with h5py.File(fname, "r") as f:
        data_full = f["strain/Strain"][:]
        dt = f["strain/Strain"].attrs["Xspacing"]
        t_start = f["meta/GPSstart"][()]
        full_duration = f["meta/Duration"][()]
        t_end = t_start + full_duration
        t = np.arange(t_start, t_end, dt)
        idx = np.where((t >= start_time) & (t < end_time))[0]

        data_full = TimeSeries(data_full, epoch = start_time, delta_t = dt)
        data_full = highpass(data_full, minimum_frequency)
        data_full = lowpass(data_full, maximum_frequency)
        data = data_full[idx]
        Data_list[det] = data

        idx2 = np.where((t >= psd_start_time) & (t < psd_end_time))[0]
        noise = data_full[idx2]
        psd = welch(x=noise, fs=4096, window=tukey_window, average="median")
        psd_patched = patch_psd(psd[0],psd[1], f_min = minimum_frequency, f_max=maximum_frequency)
        ACF = acf_from_psd(psd_patched,4096,duration*4096)
        plt.figure()
        plt.plot(ACF)
        C_inv_row[k] = inverse_circulant_first_row(ACF)

# %%
psd
# Out:
# (array([0.00000000e+00, 7.81250000e-03, 1.56250000e-02, ...,
#         2.04798438e+03, 2.04799219e+03, 2.04800000e+03],
#        shape=(262145,)),
#  array([1.75885698e-49, 5.74509757e-54, 5.73610491e-54, ...,
#         5.32622244e-65, 4.63472453e-65, 2.23482418e-65],
#        shape=(262145,)))

# %%
for k in Detectors_list.keys():
    plt.plot(Data_list[k])

# %%
import warnings

def patch_psd(freq, psd, f_min=None, f_max=None, fill_value=None, in_place=False):

    psd = psd if in_place else psd.copy()
    freq = np.asarray(freq)

    f_min = f_min or np.min(freq)
    f_max = f_max or np.max(freq)

    if f_min < np.min(freq):
        warnings.warn("f_min below PSD range; no low-frequency patching applied.")
    if f_max > np.max(freq):
        warnings.warn("f_max above PSD range; no high-frequency patching applied.")

    # Determine patch levels
    if fill_value is not None:
        # constant or tuple explicitly given
        if np.isscalar(fill_value):
            patch_low, patch_high = fill_value, fill_value
        else:
            patch_low, patch_high = fill_value
    else:
        # automatic patch levels = 10× local max just outside band
        patch_low = 1000*np.max(psd[freq < f_min]) if np.any(freq < f_min) else np.max(psd)
        patch_high = 10*np.max(psd[freq > f_max]) if np.any(freq > f_max) else np.max(psd)
    # Apply patching
    psd[freq < f_min] = patch_low
    psd[freq > f_max] = patch_high

    return psd

# %%
PSD_V1 = patch_psd(PSD_dict["V1"][0], PSD_dict["V1"][1], f_min = minimum_frequency, f_max=maximum_frequency)
PSD_L1 = patch_psd(PSD_dict["L1"][0], PSD_dict["L1"][1], f_min = minimum_frequency, f_max=maximum_frequency)

# %%
plt.loglog(PSD_dict["L1"][0],PSD_dict["L1"][1])
plt.loglog(PSD_dict["V1"][0],PSD_dict["V1"][1])
plt.axvline(maximum_frequency)

# %%
plt.loglog(PSD_dict["L1"][0],PSD_L1)
plt.loglog(PSD_dict["V1"][0],PSD_V1)
plt.axvline(maximum_frequency, linestyle="dashed")

# %%
PSD_L1,PSD_V1
# Out:
# (array([2.67461106e-32, 2.67461106e-32, 2.67461106e-32, ...,
#         1.57356850e-40, 1.57356850e-40, 1.57356850e-40],
#        shape=(262145,)),
#  array([8.22815665e-33, 8.22815665e-33, 8.22815665e-33, ...,
#         1.55120384e-38, 1.55120384e-38, 1.55120384e-38],
#        shape=(262145,)))

# %%
psd = {"L1":PSD_L1, "V1":PSD_V1}
freq = {"L1":PSD_dict["L1"][0], "V1":PSD_dict["V1"][0]}

# %%
h_waveform = {}
for k in Detectors_list.keys():
    t_delay = Detectors_list[k].time_delay_from_earth_center(
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        t_gps=fiducial_parameters["geocent_time"],
    )
    h22 = Likelihood_obj.waveform(
        fiducial_parameters,
        Time_array
        - (
            t_delay
            + fiducial_parameters["geocent_time"]
            - trigger_time
        ),
    )
    
    # Antenna pattern
    F_plus, F_cross = Detectors_list[k].antenna_pattern(
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        polarization=fiducial_parameters["psi"],
        t_gps=fiducial_parameters["geocent_time"],
    )
    h_waveform[k] = F_plus * np.real(h22) + F_cross * (-np.imag(h22))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       2 for k in Detectors_list.keys():
#       3     t_delay = Detectors_list[k].time_delay_from_earth_center(
#       4         right_ascension=fiducial_parameters["ra"],
#       5         declination=fiducial_parameters["dec"],
#       6         t_gps=fiducial_parameters["geocent_time"],
#       7     )
# ----> 8     h22 = Likelihood_obj.waveform(
#       9         fiducial_parameters,
#      10         Time_array
#      11         - (
#      12             t_delay
#      13             + fiducial_parameters["geocent_time"]
#      14             - trigger_time
#      15         ),
#      16     )
#      18     # Antenna pattern
#      19     F_plus, F_cross = Detectors_list[k].antenna_pattern(
#      20         right_ascension=fiducial_parameters["ra"],
#      21         declination=fiducial_parameters["dec"],
#      22         polarization=fiducial_parameters["psi"],
#      23         t_gps=fiducial_parameters["geocent_time"],
#      24     )
#
# NameError: name 'Likelihood_obj' is not defined

# %%
Data_dict = {"L1":Noise_dict["L1"] + h_waveform["L1"],"V1":Noise_dict["V1"] + h_waveform["V1"]}

# %%
Data_dict
# Out:
# {'L1': array([-3.45310635e-18, -3.37142043e-18, -3.28787152e-18, ...,
#         -3.70084957e-18, -3.61836991e-18, -3.53533690e-18],
#        shape=(524288,)),
#  'V1': array([3.69397833e-19, 3.85026942e-19, 4.02426007e-19, ...,
#         3.53648147e-19, 3.60979198e-19, 3.61780037e-19],
#        shape=(524288,))}

# %%
# Data_cov_psd_noise = {"Noise":Noise_dict, "C_inv_row":C_inv_row, "PSD":psd, "frequencies":freq, "Data_list":Data_dict, "Injected_waveform":Likelihood_obj.h22_fiducial}

# %%
# with open("C_inv_row_PSD_and_Noise_" + str(128) + "_sec_GW190425.pkl", "wb") as f:
    # dill.dump(Data_cov_psd_noise, f)

# %%
# frequencies = PSD_dict["L1"][0][PSD_dict["L1"][0]<=1200].copy()
# psd_values = PSD_L1[PSD_dict["L1"][0]<=1200].copy()
# # psd_values = PSD_dict["L1"][1].copy()
# psd_table = np.column_stack((frequencies, psd_values))
# np.savetxt("L1_GW190425_thin_psd.txt", psd_table, fmt="%.6e")

# %%
# frequencies = PSD_dict["V1"][0][PSD_dict["V1"][0]<=1200].copy()
# psd_values = PSD_V1[PSD_dict["V1"][0]<=1200].copy()
# # psd_values = PSD_dict["L1"][1].copy()
# psd_table = np.column_stack((frequencies, psd_values))
# np.savetxt("V1_GW190425_thin_psd.txt", psd_table, fmt="%.6e")

# %%
frequencies = PSD_dict["L1"][0].copy()
psd_values = PSD_L1.copy()
# psd_values = PSD_dict["L1"][1].copy()
psd_table = np.column_stack((frequencies, psd_values))
np.savetxt("L1_GW190425_thin_psd.txt", psd_table, fmt="%.6e")

# %%
PSD_V1
# Out:
# array([7.78650771e-36, 7.78650771e-36, 7.78650771e-36, ...,
#        7.78650771e-36, 7.78650771e-36, 7.78650771e-36],
#       shape=(262145,))

# %%
frequencies = PSD_dict["V1"][0].copy()
psd_values = PSD_V1.copy()
# psd_values = PSD_dict["V1"][1].copy()
psd_table = np.column_stack((frequencies, psd_values))
np.savetxt("V1_GW190425_thin_psd.txt", psd_table, fmt="%.6e")

# %%
Noise_dict = {}
for k in Detectors_list.keys():
    ifo = bilby.gw.detector.get_empty_interferometer(k)
    ifo.power_spectral_density = bilby.gw.detector.PowerSpectralDensity(psd_file=str(k)+"_GW190425.txt")
    ifo.minimum_frequency = 0
    ifo.maximum_frequency = 1200
    print(ifo)

    ifo.set_strain_data_from_power_spectral_density(
        sampling_frequency=4096,
        duration=128
    )
    noise = ifo.time_domain_strain
    Noise_dict[k] = noise
    time_arr = ifo.time_array
    # psd = ifo.power_spectral_density_array
    # freq = ifo.frequency_array
    plt.plot(time_arr, noise, label = k)
    # ACF = acf_from_psd(psd,4096,duration*4096)
    # C_inv_row[k] = inverse_circulant_first_row(ACF)

# plt.legend()
# Out:
# Interferometer(name='V1', power_spectral_density=PowerSpectralDensity(psd_file='V1_GW190425.txt', asd_file='None'), minimum_frequency=0.0, maximum_frequency=1200.0, length=3.0, latitude=43.631414472222225, longitude=10.504496611111112, elevation=51.884, xarm_azimuth=70.56740000000002, yarm_azimuth=160.5674, xarm_tilt=0.0, yarm_tilt=0.0)
# Interferometer(name='L1', power_spectral_density=PowerSpectralDensity(psd_file='L1_GW190425.txt', asd_file='None'), minimum_frequency=0.0, maximum_frequency=1200.0, length=4.0, latitude=30.562894333333332, longitude=-90.77424038888887, elevation=-6.574, xarm_azimuth=197.7165, yarm_azimuth=287.7165, xarm_tilt=-0.0003121, yarm_tilt=-0.0006107)

# %%
# with open("C_inv_row_" + str(128) + "_sec_GW190425.pkl", "wb") as f:
#     dill.dump(C_inv_row, f)

# %%
C_inv_V1 = inverse_circulant_first_row(acf_from_psd(PSD_V1, fs, duration*fs))
C_inv_L1 = inverse_circulant_first_row(acf_from_psd(PSD_L1, fs, duration*fs))
C_inv_row = {"V1":C_inv_V1, "L1":C_inv_L1}

# %%
C_inv_row
# Out:
# {'V1': array([5.78769653e+41, 4.53571615e+41, 2.25957386e+41, ...,
#         9.94340855e+40, 2.25957386e+41, 4.53571615e+41],
#        shape=(524288,)),
#  'L1': array([ 7.03722922e+42,  4.37165591e+42,  5.47809831e+40, ...,
#         -1.18491945e+42,  5.47809266e+40,  4.37165587e+42],
#        shape=(524288,))}

# %%
plt.plot(acf_from_psd(PSD_L1, fs, duration*fs), alpha=0.5)
plt.plot(acf_from_psd(PSD_V1, fs, duration*fs), alpha=0.5)
# plt.ylim(-1e-38, 1e-38)

# %%
C_inv_row
# Out:
# {'V1': array([5.78769653e+41, 4.53571615e+41, 2.25957386e+41, ...,
#         9.94340855e+40, 2.25957386e+41, 4.53571615e+41],
#        shape=(524288,)),
#  'L1': array([ 7.03722922e+42,  4.37165591e+42,  5.47809831e+40, ...,
#         -1.18491945e+42,  5.47809266e+40,  4.37165587e+42],
#        shape=(524288,))}

# %%
with open("C_inv_row_PSD_and_Noise_" + str(128) + "_sec_GW190425.pkl", "rb") as f:
    Inv_cov_Noise_circulant = dill.load(f)

Data_list = Inv_cov_Noise_circulant["Data_list"]
C_inv_row = Inv_cov_Noise_circulant["C_inv_row"]

# %%
epsilon1_H1, epsilon2_H1 = 0.05,0.05 #float(sys.argv[3]),float(sys.argv[4])
epsilon1_L1, epsilon2_L1 = 0.05,0.05 #float(sys.argv[5]),float(sys.argv[6])
epsilon1_V1, epsilon2_V1 = 0.05,0.05 #float(sys.argv[7]),float(sys.argv[8])

spacing1, spacing2, spacing3,spacing_times1,spacing_times2 = 1, 100, 100,0.05, 0.1 #int(sys.argv[9]),int(sys.argv[10]),int(sys.argv[11]), float(sys.argv[12]),float(sys.argv[13])

spacing = [spacing1, spacing2, spacing3]
epsilon = {"H1":np.array([epsilon1_H1,epsilon2_H1]),"L1":np.array([epsilon1_L1,epsilon2_L1]),"V1":np.array([epsilon1_V1,epsilon2_V1])}
spacing_times = [spacing_times1, spacing_times2]
print("epsilon,spacing,spacing_times",epsilon, spacing,spacing_times)

# Defining the time array:

Time_array = np.arange(start_time-trigger_time, end_time-trigger_time, 1 / 4096.0, dtype=np.float64)
print("t[0]:", Time_array[0])
print("t[-1]:",Time_array[-1])

Detectors_list = {"L1":Detector("L1"),"V1":Detector("V1")}

Likelihood_obj = RelativeBinningTimeDomain_H1detectorframe_for_longer_signals(
    time = Time_array,
    Detectors_list = Detectors_list,
    fiducial_parameters = fiducial_parameters,
    injection_parameters = None,
    Data_list = Data_list,
    C_inv_row = C_inv_row,
    Noise = {},
    trigger_time = trigger_time,
    epsilon_array_per_detector=epsilon,
    spacing=spacing,
    spacing_times=spacing_times,
)
# Out:
# epsilon,spacing,spacing_times {'H1': array([0.05, 0.05]), 'L1': array([0.05, 0.05]), 'V1': array([0.05, 0.05])} [1, 100, 100] [0.05, 0.1]
# t[0]: -127.90000009536743
# t[-1]: 0.09975576400756836

# %%
priors = bilby.gw.prior.CBCPriorDict(
    dict(
        chirp_mass=bilby.core.prior.Uniform(
            minimum=1.485,
            maximum=1.49,
            name="chirp_mass",
            latex_label="$\\mathcal{M}$",
        ),
        mass_ratio=bilby.core.prior.Uniform(
            minimum=1 / 6,
            maximum=1.0,
            name="mass_ratio",
            latex_label="$q$",
        ),
        chi_1=bilby.core.prior.Uniform(
            minimum=-0.05,
            maximum=0.05,
            name="chi_1",
            latex_label="$\\chi_1$",
        ),
        chi_2=bilby.core.prior.Uniform(
            minimum=-0.05,
            maximum=0.05,
            name="chi_2",
            latex_label="$\\chi_2$",
        ),
        luminosity_distance=bilby.gw.prior.UniformSourceFrame(
            name="luminosity_distance", minimum=10, maximum=1000, unit="Mpc"
        ),
        theta_jn=bilby.core.prior.Sine(name="theta_jn"),
        ra=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="ra", boundary="periodic"
        ),
        dec=bilby.core.prior.Cosine(name="dec"),
        psi=bilby.core.prior.Uniform(
            minimum=0, maximum=np.pi, name="psi", boundary="periodic"
        ),
        phase=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="phase", boundary="periodic"
        ),
        geocent_time=bilby.core.prior.Uniform(
            trigger_time - 0.1,
            trigger_time + 0.1,
            name="geocent_time",
            latex_label="$t_{c}$",
            boundary=None,
        ),
    )
)

# %%
Likelihood_obj.parameters.update(fiducial_parameters)
Likelihood_obj.log_likelihood_ratio()
# Out:
# np.float64(-23.185845692033844)

# %%
like = []
param = []
key = "geocent_time"
PP = []
p = fiducial_parameters.copy()
for i in range(400):
    p[key] = priors.sample()[key]
    PP.append(p)
    Likelihood_obj.parameters.update(p)
    like.append(Likelihood_obj.log_likelihood_ratio())
    param.append(p[key])

# %%
plt.scatter(param, like, marker=".")
plt.axvline(fiducial_parameters[key])
# plt.xlim(4, 5)
# plt.ylim(-10,10)

# %%
# Likelihood_obj.waveform_22_modes_fiducial(priors.sample(), Time_array)

# %%
Likelihood_obj.number_of_bins
# Out:
# {'L1': 487, 'V1': 487}

# %%
h = Likelihood_obj.h22_fiducial["L1"].copy()

# %%
# %%timeit
h[Time_array>0.01] = 0.0 + 1j*0.0
# Out:
# 201 μs ± 8.49 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
#!/usr/bin/env python
"""
Tutorial to demonstrate running parameter estimation on GW190425.

This example estimates all 17 parameters of the binary neutron star system using
commonly used prior distributions. We shall use the relative binning likelihood.
This will take around an hour to run. The data is obtained using gwpy,
see [1] for information on how to access data on the LIGO Data Grid instead.

[1] https://gwpy.github.io/docs/stable/timeseries/remote-access.html
"""
import bilby
from gwpy.timeseries import TimeSeries

logger = bilby.core.utils.logger
outdir = "outdir_FD"
label = "GW190425"

# Note you can get trigger times using the gwosc package, e.g.
# > from gwosc import datasets
# > datasets.event_gps("GW190425")
trigger_time = 1240215503.0
detectors = ["L1", "V1"]
maximum_frequency = 1200
minimum_frequency = 20
roll_off = 0.4  # Roll off duration of tukey window in seconds, default is 0.4s
duration = 128  # Analysis segment duration
post_trigger_duration = 0.1  # Time between trigger time and end of segment
end_time = trigger_time + post_trigger_duration
start_time = end_time - duration

# The fiducial parameters are taken to me the max likelihood sample from the
# posterior sample release of LIGO-Virgo
# https://www.gw-openscience.org/eventapi/html/O3_Discovery_Papers/GW190425/
# The fiducial parameters should always be in provided in the same basis as
# the sampling basis. For example, if sampling in  `mass_1` and `mass_2` instead of
# `chirp_mass` and `mass_ratio`, the fiducial parameters should also be provided in
# `mass_1` and `mass_2` below.


fiducial_parameters = {
    "chi_1": 0.01,
    "chi_2": 0.01,
    "chirp_mass": 1.48655,
    "dec": 0.0,
    "geocent_time": 1240215503.039,
    "luminosity_distance": 150,
    "mass_ratio": 0.8955,
    "phase": 3.0136566567608765,
    "psi": 0.281,
    "ra": 4.2,
    "theta_jn": 0.6,
}

psd_duration = 1024
psd_start_time = start_time - psd_duration
psd_end_time = start_time

with open("C_inv_row_PSD_and_Noise_" + str(128) + "_sec_GW190425.pkl", "rb") as f:
    Inv_cov_Noise_circulant = dill.load(f)

Data_list = Inv_cov_Noise_circulant["Data_list"]
PSD_dict = Inv_cov_Noise_circulant["PSD"]
Freq_dict = Inv_cov_Noise_circulant["frequencies"]
dt = 1/4096
# We now use gwpy to obtain analysis and psd data and create the ifo_list
ifo_list = bilby.gw.detector.InterferometerList([])
for det in detectors:
    data = Data_list[det]
    data = TimeSeries(data, t0 = start_time, dt = dt)
    ifo = bilby.gw.detector.get_empty_interferometer(det)
    ifo.strain_data.set_from_gwpy_timeseries(data)

    psd = PSD_dict[det]
    psd = TimeSeries(psd, t0 = psd_start_time, dt = dt)
    ifo.power_spectral_density = bilby.gw.detector.PowerSpectralDensity(
        frequency_array=Freq_dict[det], psd_array=psd
    )
    ifo.maximum_frequency = maximum_frequency
    ifo.minimum_frequency = minimum_frequency
    ifo_list.append(ifo)

plt.figure()
for ifo in ifo_list:
    plt.loglog(ifo.frequency_array, np.abs(ifo.strain_data.frequency_domain_strain), label = ifo.name)

plt.figure()
for ifo in ifo_list:
    plt.loglog(ifo.power_spectral_density.frequency_array, ifo.power_spectral_density_array)

logger.info("Saving data plots to {}".format(outdir))
bilby.core.utils.check_directory_exists_and_if_not_mkdir(outdir)
ifo_list.plot_data(outdir=outdir, label=label)

priors = bilby.gw.prior.CBCPriorDict(
    dict(
        chirp_mass=bilby.core.prior.Uniform(
            minimum=1.485,
            maximum=1.49,
            name="chirp_mass",
            latex_label="$\\mathcal{M}$",
        ),
        mass_ratio=bilby.core.prior.Uniform(
            minimum=1 / 6,
            maximum=1.0,
            name="mass_ratio",
            latex_label="$q$",
        ),
        chi_1=bilby.core.prior.Uniform(
            minimum=-0.05,
            maximum=0.05,
            name="chi_1",
            latex_label="$\\chi_1$",
        ),
        chi_2=bilby.core.prior.Uniform(
            minimum=-0.05,
            maximum=0.05,
            name="chi_2",
            latex_label="$\\chi_2$",
        ),
        luminosity_distance=bilby.gw.prior.UniformSourceFrame(
            name="luminosity_distance", minimum=10, maximum=1000, unit="Mpc"
        ),
        theta_jn=bilby.core.prior.Sine(name="theta_jn"),
        ra=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="ra", boundary="periodic"
        ),
        dec=bilby.core.prior.Cosine(name="dec"),
        psi=bilby.core.prior.Uniform(
            minimum=0, maximum=np.pi, name="psi", boundary="periodic"
        ),
        phase=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="phase", boundary="periodic"
        ),
    )
)
# Add the geocent time prior
priors["geocent_time"] = bilby.core.prior.Uniform(
    trigger_time - 0.1, trigger_time + 0.1, name="geocent_time"
)

# In this step we define a `waveform_generator`. This is the object which
# creates the frequency-domain strain. In this instance, we are using the
# `lal_binary_black_hole model` source model. We also pass other parameters:
# the waveform approximant and reference frequency and a parameter conversion
# which allows us to sample in chirp mass and ratio rather than component mass
waveform_generator = bilby.gw.WaveformGenerator(
    frequency_domain_source_model=bilby.gw.source.lal_binary_neutron_star_relative_binning,
    parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_neutron_star_parameters,
    waveform_arguments={
        "waveform_approximant": "IMRPhenomPv2",
        "reference_frequency": 20,
    },
)

# In this step, we define the likelihood. Here we use the standard likelihood
# function, passing it the data and the waveform generator.
# Note, phase_marginalization is formally invalid with a precessing waveform such as IMRPhenomPv2
likelihood = bilby.gw.likelihood.RelativeBinningGravitationalWaveTransient(
    ifo_list,
    waveform_generator,
    priors=priors,
    time_marginalization=False,
    phase_marginalization=False,
    distance_marginalization=False,
    fiducial_parameters=fiducial_parameters,
)

# result = bilby.run_sampler(
#     likelihood=likelihood,
#     priors=priors,
#     nlive=500,
#     label=label,
#     outdir=outdir,
#     sampler="dynesty",
#     sample="acceptance-walk",
#     naccept=60,
#     npool=16,
# )
# Out:
# 21:40 bilby INFO    : Saving data plots to outdir_FD
# 21:40 bilby INFO    : Waveform generator instantiated: WaveformGenerator(duration=None, sampling_frequency=None, start_time=0, frequency_domain_source_model=bilby.gw.source.lal_binary_neutron_star_relative_binning, time_domain_source_model=None, parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_neutron_star_parameters, waveform_arguments={'waveform_approximant': 'IMRPhenomPv2', 'reference_frequency': 20})
# 21:40 bilby INFO    : Initial fiducial waveforms set up
# 21:40 bilby INFO    : Summary Data Obtained
# 21:40 bilby INFO    : Fiducial likelihood: -12.13
