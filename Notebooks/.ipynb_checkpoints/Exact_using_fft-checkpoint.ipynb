# %%
import numpy as np
import lal
import lalsimulation as ls
import matplotlib.pyplot as plt
from pycbc.waveform import get_td_waveform
from bilby.gw.conversion import chirp_mass_and_mass_ratio_to_component_masses
import bilby
from pycbc.detector import Detector
from pycbc.conversions import det_tc
import dill
# import ringdown
import time
from scipy.linalg import toeplitz, inv
from scipy.optimize import differential_evolution
import sys
sys.path.append('/home/neha/Relative-binning-time-domain/Trying_something_new/')
from Relative_22_using_cov_row_new import *
import scipy.signal as sig
# import warnings
# Out:
# /tmp/ipykernel_51648/3229693554.py:2: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# lal.MSUN_SI != Msun
# /home/neha/local/lalsuite/lib/python3.12/site-packages/lalsimulation/__init__.py

# %%
r_0 = np.random.uniform(0,1, (5, 1000))
A_0 = np.random.uniform(0,1, (5, 1000))
r_1 = np.random.uniform(0,1, (5, 1000))
A_1 = np.random.uniform(0,1, (5, 1000))

# %%
# %%timeit 

np.sum(r_0 * A_0, axis=-1) + np.sum(r_1 * A_1, axis=-1)
# Out:
# 14 μs ± 173 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit

np.einsum("...i,...i->...", r_0, A_0) + np.einsum(
                "...i,...i->...", r_1, A_1
            )
# Out:
# 11.6 μs ± 187 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
np.sum(r_0 * A_0, axis=-1) + np.sum(r_1 * A_1, axis=-1), np.einsum("...i,...i->...", r_0, A_0) + np.einsum(
                "...i,...i->...", r_1, A_1
            )
# Out:
# (array([501.77035893, 495.95620137, 499.62255476, 491.45875748,
#         501.7794022 ]),
#  array([501.77035893, 495.95620137, 499.62255476, 491.45875748,
#         501.7794022 ]))

# %%
from ncon import ncon

# %%
# %%timeit
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
n = 1200
b = np.random.uniform(0,1,n)
a = np.random.uniform(0,1,n)

# %%
import time

# %%
N = 1000000

# %%
start_time = time.time()
for i in range(N):
    c = np.dot(a,b)

print(time.time()-start_time)

# %%
start_time = time.time()
for i in range(N):
    d = np.einsum("i,i->",a,b)

print(time.time()-start_time)

# %%
start_time = time.time()
for i in range(N):
    e = ncon([a, b], [[1], [1]])

print(time.time()-start_time)

# %%
c-d

# %%
c-e

# %%
# %%timeit

np.dot(a,b)

# %%
# %%timeit
np.einsum("i,i->",a,b)

# %%
# %%timeit
np.einsum("i,i->",a,b, optimize=True)

# %%
# %%timeit
ncon([a, b], [[1], [1]])

# %%
def SNR_using_bilby(fiducial_parameters):
    duration = 128.0
    sampling_frequency = 4096.0
    minimum_frequency = 20

    injection_parameters2 = fiducial_parameters.copy()
    injection_parameters2["mass_1"], injection_parameters2["mass_2"] = (
        chirp_mass_and_mass_ratio_to_component_masses(
            injection_parameters2["chirp_mass"], injection_parameters2["mass_ratio"]
        )
    )
    injection_parameters2.pop("chirp_mass")
    injection_parameters2.pop("mass_ratio")

    # Fixed arguments passed into the source model
    waveform_arguments = dict(
        waveform_approximant="IMRPhenomT",
        reference_frequency=20,
        minimum_frequency=minimum_frequency,
    )

    # Create the waveform_generator using a LAL BinaryBlackHole source function
    waveform_generator = bilby.gw.WaveformGenerator(
        duration=duration,
        sampling_frequency=sampling_frequency,
        frequency_domain_source_model=bilby.gw.source.lal_binary_neutron_star,
        parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_neutron_star_parameters,
        waveform_arguments=waveform_arguments,
        parameters=injection_parameters2,
    )

    # Set up interferometers.  In this case we'll use two interferometers
    # (LIGO-Hanford (H1), LIGO-Livingston (L1). These default to their design
    # sensitivity
    ifos = bilby.gw.detector.InterferometerList(["H1", "L1","V1"])
    ifos[0].minimum_frequency = 20
    ifos[1].minimum_frequency = 20
    ifos.set_strain_data_from_zero_noise(
        sampling_frequency=sampling_frequency,
        duration=duration,
        start_time=fiducial_parameters["geocent_time"],
    )
    ifos.inject_signal(
        waveform_generator=waveform_generator, parameters=injection_parameters2
    )
    likelihood = bilby.gw.likelihood.GravitationalWaveTransient(
        interferometers=ifos,
        waveform_generator=waveform_generator,
        time_reference = "H1"
    )
    return {
        "L1": ifos.meta_data["L1"]["matched_filter_SNR"].real,
        "H1": ifos.meta_data["H1"]["matched_filter_SNR"].real,
        "V1": ifos.meta_data["V1"]["matched_filter_SNR"].real
    }, np.sqrt(
        (ifos.meta_data["L1"]["matched_filter_SNR"].real) ** 2
        + (ifos.meta_data["H1"]["matched_filter_SNR"].real) ** 2
    + (ifos.meta_data["V1"]["matched_filter_SNR"].real) ** 2),likelihood

# %%
priors = bilby.gw.prior.CBCPriorDict(
    dict(
        chirp_mass=bilby.core.prior.Uniform(
            minimum=25,
            maximum=60,
            name="chirp_mass",
            latex_label="$\\mathcal{M}$",
        ),
        mass_ratio=bilby.core.prior.Uniform(
            minimum=1 / 6,
            maximum=1.0,
            name="mass_ratio",
            latex_label="$q$",
        ),
        chi_1=bilby.core.prior.Uniform(
            minimum=-0.99,
            maximum=0.99,
            name="chi_1",
            latex_label="$\\chi_1$",
        ),
        chi_2=bilby.core.prior.Uniform(
            minimum=-0.99,
            maximum=0.99,
            name="chi_2",
            latex_label="$\\chi_2$",
        ),
        luminosity_distance=bilby.gw.prior.UniformSourceFrame(
            name="luminosity_distance", minimum=1e1, maximum=1000, unit="Mpc"
        ),
        theta_jn=bilby.core.prior.Sine(name="theta_jn"),
        ra=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="ra", boundary="periodic"
        ),
        dec=bilby.core.prior.Cosine(name="dec"),
        psi=bilby.core.prior.Uniform(
            minimum=0, maximum=np.pi, name="psi", boundary="periodic"
        ),
        phase=bilby.core.prior.Uniform(
            minimum=0, maximum=2 * np.pi, name="phase", boundary="periodic"
        ),
        geocent_time=bilby.core.prior.Uniform(
            1126259462.413 - 0.1,
            1126259462.413 + 0.1,
            name="geocent_time",
            latex_label="$t_c$",
        ),
    )
)

# %%
class RelativeBinningTimeDomain_H1detectorframe_for_longer_signals_new(bilby.Likelihood):
    """
    Parameters
    ----------
    time : 1D array
        An array of time points at which waveform/data is generated.
    Detectors_list : list
        List of detector names (pycbc.detector.Detector)
    fiducial_parameters : dict
        Dictionary of fiducial parameters.
    injection_parameters : dict
        Dictionary of injection parameters.
    Data_list : list
        List containing the observed data from each detector.
    C_inv_row : array-like
        1st row of the inverse covariance matrix.
    Noise : array-like
        Noise properties of the detectors.
    epsilon : float, optional (default=0.1)
        A tolerance value used to determine the size of time bins.
        The smaller value of epsilon generates bins of smaller size, resulting in more number of bins.
        If epsilon is too small, then the size of bins may be smaller than the sampling frequency.
        We require that each bin contain atleast one time point.
    spacing : list, optional (default=[1, 10, 100])
        Number of time points in each time bin (only for merger and ringdown part for 0.0 < self.time < 0.1)
    priors : dict, optional
        Prior distributions for the model parameters.
    
    Notes
    -----
    This class uses IMRPhenomT waveform approximant for generating waveforms.
    """
    def __init__(
        self,
        time,
        Detectors_list,
        fiducial_parameters,
        injection_parameters,
        Data_list,
        C_inv_row,
        Noise,
        epsilon_array_per_detector={
            "H1": np.array([0.5, 0.1]),
            "L1": np.array([0.5, 0.1]),
            "V1": np.array([0.5, 0.1]),
        },
        spacing=np.array([1, 10, 100]),
        spacing_times=np.array([0.02, 0.1]),
        time_split_per_detector={"H1": -0.02, "L1": -0.02, "V1": -0.02},
        priors=None,
    ):
        super().__init__(
            parameters={}
        )
        self.gamma = np.array([5 / 8, 3 / 8, 1 / 4, 1 / 8, -1 / 8, -1 / 4])
        self.chi = 1
        self.time = time
        self.epsilon_array_per_detector = epsilon_array_per_detector
        self.spacing = spacing
        self.spacing_times = spacing_times
        self.time_split_per_detector = time_split_per_detector
        self.Detectors_list = Detectors_list
        self.Noise = Noise
        if fiducial_parameters is None:
            fiducial_parameters = priors.sample()
        self.fiducial_parameters = fiducial_parameters.copy()
        self.injection_parameters = injection_parameters.copy()
        self.C_inv_row = C_inv_row
        self.noise_log_likelihood_value = None
        self._Data_list = Data_list if Data_list else {}

        self.compute_SNR_TD_and_waveform_data()
        self.setup_bins_per_detector()
        self.Summary_data()
        self.create_lalparams_with_modes()

        # self.dispatch = {det: self.log_likelihood_per_detector_using_einsum if count < 250 else self.log_likelihood_per_detector_using_ncon for det, count in (self.number_of_bins).items()}

    @property
    def injection_parameters(self):
        return self._injection_parameters

    @injection_parameters.setter
    def injection_parameters(self, new_params):
        self._injection_parameters = new_params.copy()
        self._Data_list = {}  # Set Data_list = 0 if injection params are changed.

    @property
    def Data_list(self):
        return self._Data_list

    def create_lalparams_with_modes(self):
        # For self.waveform_22_modes() function:
        lalParams_positive_m = lal.CreateDict()
        ModeArray_positive_m = ls.SimInspiralCreateModeArray()
        
        for l, m in [(2, 2)]:
            ls.SimInspiralModeArrayActivateMode(ModeArray_positive_m, l, m)
        ls.SimInspiralWaveformParamsInsertModeArray(
            lalParams_positive_m, ModeArray_positive_m
        )
        self.lalParams_positive_m = lalParams_positive_m

    def inner_product_TD(self, h1, h2, InvCov):
        """
        Computes inner product between h1, InvCov and h2.

        Parameters
        ----------
        h1 : 1D array
            Data or waveform
        h2 : 1D array
            Data or waveform
        InvCov : Ndarray
            Inverse of n-dimensional covariance matrix

        Returns
        -------
        Inner product : float
            Inner product between h1, InvCov, h2, calculated as
            Sum_{ij} h1_i C^{-1}_{ij} h2_j
        """
        return np.dot(h1, np.matmul(InvCov, h2))
    
    def weighted_inner_product_circulant(self, h1, h2,  C_inv_row):
        """
        Compute (h1, C^-1 h2) using FFT-based convolution.
        """
        C_inv_h2 = self.vector_circulant_matrix_multiply(h2,  C_inv_row)
        return np.dot(h1, C_inv_h2)

    def vector_circulant_matrix_multiply(self, h,  C_inv_row):
        """
        Compute C^-1 h using FFT-based circular convolution.
        """
        fft_C = np.fft.fft(C_inv_row)
        fft_h = np.fft.fft(h)
        result = np.fft.ifft(fft_C * fft_h).real
        return result

    def compute_SNR_TD_and_waveform_data(self):
        """
        Computes fiducial waveform (or 22 mode), total SNR and inner product between data, inverse-covariance matrix and data.
        """
        data_times_C_inv = {}
        Antenna_pattern_dict = {}
        data_times_C_inv_times_data = {}
        # Generating 22-mode using fiducial parameters. We require this to compute summary data and likelihood.
        h22_fiducial = {}
        # Generating plus and cross polarizations to compute SNR and data.
        h_injection = {}
        Time_array_per_detector = {}
        t_delay_injection_dict = {}

        for k in self.Detectors_list.keys():

            t_delay_injection = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.injection_parameters["ra"],
                declination=self.injection_parameters["dec"],
                t_gps=self.injection_parameters["H1_time"],
            )
            t_delay_fiducial = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.fiducial_parameters["ra"],
                declination=self.fiducial_parameters["dec"],
                t_gps=self.fiducial_parameters["H1_time"],
            )
            Time_array_per_detector[k] = self.time + t_delay_injection
            t_delay_injection_dict[k] = t_delay_injection

            h22_fiducial[k] = self.waveform_22_modes(
                self.fiducial_parameters, Time_array_per_detector[k] - t_delay_fiducial
            )
            h_injection[k] = self.waveform(
                self.injection_parameters, Time_array_per_detector[k] - t_delay_injection
            )

            F_plus, F_cross = self.Detectors_list[k].antenna_pattern(
                right_ascension=self.injection_parameters["ra"],
                declination=self.injection_parameters["dec"],
                polarization=self.injection_parameters["psi"],
                t_gps=self.injection_parameters["H1_time"],
            )
            Antenna_pattern_dict[k] = {"F_plus": F_plus, "F_cross": F_cross}

            if (
                k not in self.Data_list
                or self.Data_list[k] is None
                or len(self.Data_list[k]) == 0
            ):
                data = (
                    F_plus * np.real(h_injection[k])
                    - F_cross * np.imag(h_injection[k])
                    + self.Noise[k]
                )
                self.Data_list[k] = data
            data_times_C_inv[k] = self.vector_circulant_matrix_multiply(self.Data_list[k],self.C_inv_row[k])
            data_times_C_inv_times_data[k] = self.weighted_inner_product_circulant(
                self.Data_list[k], self.Data_list[k], self.C_inv_row[k]
            )
        self.data_times_C_inv_times_data = data_times_C_inv_times_data
        self.Time_array_per_detector = Time_array_per_detector
        self.data_times_C_inv = data_times_C_inv
        self.h22_fiducial = h22_fiducial
        self.h_injection = h_injection
        self.t_delay_injection_dict = t_delay_injection_dict

        SNR_dict = {}
        SNR_arr = []
        for k in self.Detectors_list.keys():
            signal = Antenna_pattern_dict[k]["F_plus"] * np.real(
                self.h_injection[k]
            ) + Antenna_pattern_dict[k]["F_cross"] * (-np.imag(self.h_injection[k]))
            hh = self.weighted_inner_product_circulant(signal, signal, self.C_inv_row[k])
            dh = self.weighted_inner_product_circulant(self.Data_list[k], signal, self.C_inv_row[k])
            SNR = np.abs(dh) / np.sqrt(np.abs(hh))
            SNR_arr.append(SNR)
            SNR_dict[k] = SNR
        self.SNR_dict = SNR_dict
        return (
            self.SNR_dict,
            np.sqrt(np.sum(np.array(SNR_arr) ** 2)),
            self.h_injection,
            self.Data_list,
            self.data_times_C_inv,
        )

    # def full_waveform(self, h1, ho, TimeArray):
    #     """
    #     Computes target waveform (or mode (h^{lm})) at each time point using the ratio of target waveform (or mode) generated at bin edges to the fiducial waveform (or mode).

    #     Parameters
    #     ----------
    #     h1 : 1D array
    #         Target waveform or mode, generated only at bin edges
    #     ho : 1D array
    #         Fiducial waveform or mode, generated at each time point

    #     Returns
    #     -------
    #     h_full : 1D array
    #         Target waveform at each time point, calculated as
    #         h(t) = r(t) ho(t)  OR  h^{lm}(t) = r^{lm}(t) ho^{lm}(t)
    #     """
    #     waveform_ratio = h1 / ho[self.bin_edge_index]

    #     r_o = (waveform_ratio[1:] + waveform_ratio[:-1]) / 2
    #     r_1 = (waveform_ratio[1:] - waveform_ratio[:-1]) / self.bin_width

    #     h_ratio = np.zeros(len(TimeArray), dtype="complex")

    #     for i in range(self.number_of_bins):
    #         start_index = self.bin_edge_index[i]
    #         end_index = self.bin_edge_index[i + 1]
    #         index = np.arange(start_index, end_index + 1, 1)
    #         time_per_bin = TimeArray[index]
    #         h_ratio[index] = r_o[i] + r_1[i] * (time_per_bin - self.bin_centre[i])
    #     h_full = h_ratio * ho
    #     return h_full

    def waveform(self, parameters, Time_array, fmin=20, fref=20, dT=1 / 4096.0):
        """
        Computes time-domain waveform (approximant - IMRPhenomT).

        Parameters
        ----------
        parameters : dict
            A dictionary containing the parameters of binary system.
        time : 1D array
            A numpy array of time points at which the h22 mode is to be computed.

        Returns
        -------
        h : 1D array
            time-domain waveform
        """
        chirp_mass, mass_ratio, chi_1, chi_2, luminosity_distance, theta_jn, phase = (
            parameters["chirp_mass"],
            parameters["mass_ratio"],
            parameters["chi_1"],
            parameters["chi_2"],
            parameters["luminosity_distance"],
            parameters["theta_jn"],
            parameters["phase"],
        )
        m1, m2 = chirp_mass_and_mass_ratio_to_component_masses(chirp_mass, mass_ratio)
        Time_array_lal_sequence = lal.CreateREAL8Sequence(len(Time_array))
        Time_array_lal_sequence.data = Time_array / ((m1 + m2) * lal.MTSUN_SI)
        h = ls.SimIMRPhenomT_neha(
            m1 * lal.MSUN_SI,
            m2 * lal.MSUN_SI,
            chi_1,
            chi_2,
            luminosity_distance * 1e6 * lal.PC_SI,
            theta_jn,
            dT,
            fmin,
            fref,
            phase,
            Time_array_lal_sequence,
            None,
        )
        return h[0].data.data - 1j * h[1].data.data

    def waveform_22_modes(
        self, parameters, Time_array, fmin=20, fref=20, dT=1 / 4096.0
    ):
        """
        Computes time-domain 22 mode (h22).
        (approximant - IMRPhenomT)

        Parameters
        ----------
        parameters : dict
            A dictionary containing the parameters of binary system.
        time : 1D array
            A numpy array of time points at which the h22 mode is to be computed.

        Returns
        -------
        h22 : 1D array
            time-domain 22 mode (h22)
        """
        chirp_mass, mass_ratio, chi_1, chi_2, luminosity_distance, phase = (
            parameters["chirp_mass"],
            parameters["mass_ratio"],
            parameters["chi_1"],
            parameters["chi_2"],
            parameters["luminosity_distance"],
            parameters["phase"],
        )
        m1, m2 = chirp_mass_and_mass_ratio_to_component_masses(chirp_mass, mass_ratio)
        Time_array_lal_sequence = lal.CreateREAL8Sequence(len(Time_array))
        Time_array_lal_sequence.data = Time_array / ((m1 + m2) * lal.MTSUN_SI)
        h = ls.SimIMRPhenomT_neha_just_modes(
            m1 * lal.MSUN_SI,
            m2 * lal.MSUN_SI,
            chi_1,
            chi_2,
            luminosity_distance * 1e6 * lal.PC_SI,
            dT,
            fmin,
            fref,
            phase,
            Time_array_lal_sequence,
            None,
        )
        return h.mode.data.data

    def waveform_22_modes_2(
        self, parameters, Time_array, fmin=20, fref=20, dT=1 / 4096.0
    ):
        """
        Computes time-domain 22 mode (h22).
        (approximant - IMRPhenomT)

        Parameters
        ----------
        parameters : dict
            A dictionary containing the parameters of binary system.
        time : 1D array
            A numpy array of time points at which the h22 mode is to be computed.

        Returns
        -------
        h22 : 1D array
            time-domain 22 mode (h22)
        """
        chirp_mass, mass_ratio, chi_1, chi_2, luminosity_distance, phase = (
            parameters["chirp_mass"],
            parameters["mass_ratio"],
            parameters["chi_1"],
            parameters["chi_2"],
            parameters["luminosity_distance"],
            parameters["phase"],
        )
        m1, m2 = chirp_mass_and_mass_ratio_to_component_masses(chirp_mass, mass_ratio)
        Time_array_lal_sequence = lal.CreateREAL8Sequence(len(Time_array))
        Time_array_lal_sequence.data = Time_array / ((m1 + m2) * lal.MTSUN_SI)
        h = ls.SimIMRPhenomTHM_Modes_neha(
            m1 * lal.MSUN_SI,
            m2 * lal.MSUN_SI,
            chi_1,
            chi_2,
            luminosity_distance * 1e6 * lal.PC_SI,
            dT,
            fmin,
            fref,
            phase,
            Time_array_lal_sequence,
            self.lalParams_positive_m,
        )
        return h.mode.data.data

    def setup_bins_inspiral(self, Time_array, time_split, epsilon_array):
        """
        Constructs non-uniform time bins for inspiral part.
        The method for bin construction is similar to the one presented in
        https://arxiv.org/abs/1806.08792.

        Returns
        -------
        number_of_bins : float
            Total number of bins constructed for inspiral part
        bin_edge_index : 1D array
            Indices corresponding to the edge of time bins
        bin_centre : 1D array
            Centre of each time bin
        bin_width : 1D array
            Width of each time bin
        time_on_edge : 1D array
            The time value at each bin edge

        Variables
        ----------
        epsilon : float
            A tolerance value used to determine the size of time bins.
            The smaller value of epsilon generates bins of smaller size, resulting in more number of bins.
            If epsilon is too small, then the size of bins may be smaller than the sampling frequency.
            We require that each bin contain atleast one time point.
        """

        d_alpha = []
        for g in self.gamma:
            if g < 0:
                d_alpha.append(2 * np.pi * self.chi / (min(abs(Time_array))) ** g)
            else:
                d_alpha.append(2 * np.pi * self.chi / (max(abs(Time_array))) ** g)
        d_alpha = np.array(d_alpha)

        d_phi_f = np.sum(
            np.sign(self.gamma) * d_alpha * (abs(Time_array[:, None]) ** self.gamma),
            axis=1,
        )

        mask1 = Time_array <= time_split
        mask2 = Time_array > time_split
        d_phi_f_regions = [d_phi_f[mask1], d_phi_f[mask2]]
        idx_offsets = [0, np.sum(mask1)]

        bin_edge_indices = []
        for region_idx, (d_phi_f_reg, e) in enumerate(
            zip(d_phi_f_regions, epsilon_array)
        ):
            number_of_bins = int(abs((d_phi_f_reg[-1] - d_phi_f_reg[0]) / e))

            region_bin_edges = []
            for i in range(number_of_bins + 1):
                bin_idx = np.where(
                    d_phi_f_reg - d_phi_f_reg[0]
                    >= (i / number_of_bins) * (d_phi_f_reg[-1] - d_phi_f_reg[0])
                )[0]
                if len(bin_idx) > 0:
                    region_bin_edges.append(bin_idx[-1])
                else:
                    region_bin_edges.append(0)

            region_bin_edges = np.array(region_bin_edges) + idx_offsets[region_idx]
            bin_edge_indices.extend(region_bin_edges)

        bin_edge_index = np.unique(np.array(bin_edge_indices))
        time_on_edge = Time_array[bin_edge_index]
        bin_width = time_on_edge[1:] - time_on_edge[:-1]
        bin_centre = (time_on_edge[1:] + time_on_edge[:-1]) / 2
        number_of_bins = len(bin_centre)
        return (number_of_bins, bin_edge_index, bin_centre, bin_width, time_on_edge)

    def setup_bins(self, Time_array_full, time_split, epsilon_array):
        """
        Constructs time bins for entire time range.

        Returns
        -------
        number_of_bins : float
            Total number of bins created for entire time range
        bin_edge_index : 1D array
            Indices corresponding to the edge of time bins
        bin_centre : 1D array
            Centre of each time bin
        bin_width : 1D array
            Width of each time bin
        time_on_edge : 1D array
            The time value at each bin edge

        Variables
        ---------
        spacing : float
            Number of time points in each time bin (only for merger and ringdown part for 0.0 < self.time < 0.1)
        """
        idx_inspiral_end = np.where(Time_array_full < -0.0)[0][-1]
        Time_array_inspiral = Time_array_full[: idx_inspiral_end + 1]
        bin_edge_index_insp = self.setup_bins_inspiral(
            Time_array_inspiral, time_split, epsilon_array
        )[1]

        # We construct uniform time bins for merger and ringdwon part.

        spacing_t_less_t1 = self.spacing[0]  # Spacing for t < t1
        spacing_t_t1_to_t2 = self.spacing[1]  # Spacing for t1 =< t < t2
        spacing_t_greater_t2 = self.spacing[2]  # Spacing for t >= t2

        idx_merger_ringdown_start = idx_inspiral_end
        if Time_array_full[-1] > self.spacing_times[0]:
            idx_t_t1 = np.where(Time_array_full > self.spacing_times[0])[0][0]
        else:
            idx_t_t1 = int(len(Time_array_full))
        if Time_array_full[-1] > self.spacing_times[1]:
            idx_t_t2 = np.where(Time_array_full > self.spacing_times[1])[0][0]
        else:
            idx_t_t2 = int(len(Time_array_full))

        # Define bins in the three different regions : t < t1, t = t1 to t2 and t > t2
        bins_t_less_t1 = np.arange(
            idx_merger_ringdown_start, idx_t_t1, spacing_t_less_t1
        )
        if Time_array_full[-1] > self.spacing_times[0]:
            bins_t_t1_to_t2 = np.arange(idx_t_t1, idx_t_t2, spacing_t_t1_to_t2)
        else:
            bins_t_t1_to_t2 = np.array([], dtype=int)
        if Time_array_full[-1] > self.spacing_times[1]:
            bins_t_greater_t2 = np.arange(
                idx_t_t2, len(Time_array_full), spacing_t_greater_t2
            )
        else:
            bins_t_greater_t2 = np.array([], dtype=int)
        # Combine all bins
        bin_edge_index = np.concatenate(
            (
                bin_edge_index_insp,
                bins_t_less_t1[1:],
                bins_t_t1_to_t2[1:],
                bins_t_greater_t2[1:],
            ),
            dtype=int,
        )

        if bin_edge_index[-1] != len(Time_array_full) - 1:
            bin_edge_index = np.insert(
                bin_edge_index, len(bin_edge_index), len(Time_array_full) - 1
            )
        time_on_edge = Time_array_full[bin_edge_index]
        bin_width = time_on_edge[1:] - time_on_edge[:-1]
        bin_centre = (time_on_edge[1:] + time_on_edge[:-1]) / 2
        number_of_bins = len(bin_centre)
        return (time_on_edge, number_of_bins, bin_edge_index, bin_centre, bin_width)

    def setup_bins_per_detector(self):
        (
            time_on_edge_per_detector,
            number_of_bins_per_detector,
            bin_edge_index_per_detector,
            bin_centre_per_detector,
            bin_width_per_detector,
        ) = ({}, {}, {}, {}, {})
        k = "H1"
        time_on_edge, number_of_bins, bin_edge_index, bin_centre, bin_width = (
            self.setup_bins(
                self.Time_array_per_detector[k],
                self.time_split_per_detector[k],
                self.epsilon_array_per_detector[k]
            )
        )
        for k in self.Detectors_list.keys():
            time_on_edge_per_detector[k] = time_on_edge.copy() + self.t_delay_injection_dict[k]
            number_of_bins_per_detector[k] = number_of_bins
            bin_edge_index_per_detector[k] = bin_edge_index.copy()
            bin_centre_per_detector[k] = bin_centre.copy() + self.t_delay_injection_dict[k]
            bin_width_per_detector[k] = bin_width.copy()

        self.time_on_edge = time_on_edge_per_detector
        self.number_of_bins = number_of_bins_per_detector
        self.bin_edge_index = bin_edge_index_per_detector
        self.bin_centre = bin_centre_per_detector
        self.bin_width = bin_width_per_detector
    
    def Summary_data(self):
        """
        Computes summary data using FFT-based convolution for efficient B-matrix computation.
        """
        Summary_data_dict = {}

        for k in self.Detectors_list.keys():
            time_diff_arr = np.zeros_like(self.Time_array_per_detector[k], dtype=float)
            for i in range(self.number_of_bins[k]):
                start_index = self.bin_edge_index[k][i]
                end_index = self.bin_edge_index[k][i + 1]
                time_diff_arr[start_index:end_index] = (
                    self.Time_array_per_detector[k][start_index:end_index]
                    - self.bin_centre[k][i]
                )
            h = self.h22_fiducial[k]
            h_t = h * time_diff_arr
            h_conj = np.conjugate(h)
            C_inv = self.C_inv_row[k]
            fft_C = np.fft.fft(C_inv)

            data_times_C_inv_times_h22 = self.data_times_C_inv[k] * h
            data_times_C_inv_times_h22_times_time_diff = data_times_C_inv_times_h22 * time_diff_arr

            A_0 = np.zeros(self.number_of_bins[k], dtype=complex)
            A_1 = np.zeros(self.number_of_bins[k], dtype=complex)

            for b1 in range(self.number_of_bins[k]):
                start_index = self.bin_edge_index[k][b1]
                if b1 == self.number_of_bins[k] - 1:
                    # If last bin, include the last index in the bin
                    end_index = self.bin_edge_index[k][b1 + 1] + 1
                else:
                    # Else, do not include the last index in the bin
                    end_index = self.bin_edge_index[k][b1 + 1]

                A_0[b1] = np.sum(data_times_C_inv_times_h22[start_index:end_index])
                A_1[b1] = np.sum(
                    data_times_C_inv_times_h22_times_time_diff[start_index:end_index]
                )

            B_0 = np.zeros(
                (self.number_of_bins[k], self.number_of_bins[k]), dtype=complex
            )
            B_1 = np.zeros(
                (self.number_of_bins[k], self.number_of_bins[k]), dtype=complex
            )
            B_2 = np.zeros(
                (self.number_of_bins[k], self.number_of_bins[k]), dtype=complex
            )
            B_3 = np.zeros(
                (self.number_of_bins[k], self.number_of_bins[k]), dtype=complex
            )
                
            for b2 in range(self.number_of_bins[k]):
                start_index_b2 = self.bin_edge_index[k][b2]
                if b2 == self.number_of_bins[k] - 1:
                    # If last bin, include the last index in the bin
                    end_index_b2 = self.bin_edge_index[k][b2 + 1] + 1
                else:
                    # Else, do not include the last index in the bin
                    end_index_b2 = self.bin_edge_index[k][b2 + 1]

                h_bin = np.zeros_like(h)
                h_bin_t = np.zeros_like(h_t)
                h_bin[start_index_b2:end_index_b2] = h[start_index_b2:end_index_b2]
                h_bin_t[start_index_b2:end_index_b2] = h_t[start_index_b2:end_index_b2]
                fft_h = np.fft.fft(h_bin)
                fft_h_t = np.fft.fft(h_bin_t)
                conv1 = np.fft.ifft(fft_C * fft_h)
                conv2 = np.fft.ifft(fft_C * fft_h_t)

                for b1 in range(self.number_of_bins[k]):
                    start_index_b1 = self.bin_edge_index[k][b1]
                    if b1 == self.number_of_bins[k] - 1:
                        # If last bin, include the last index in the bin
                        end_index_b1 = self.bin_edge_index[k][b1 + 1] + 1
                    else:
                        # Else, do not include the last index in the bin
                        end_index_b1 = self.bin_edge_index[k][b1 + 1]

                    B_0[b1, b2] = np.dot(h[start_index_b1:end_index_b1], conv1[start_index_b1:end_index_b1])
                    B_1[b1, b2] = np.dot(h[start_index_b1:end_index_b1], conv2[start_index_b1:end_index_b1])
                    B_2[b1, b2] = np.dot(h_conj[start_index_b1:end_index_b1], conv1[start_index_b1:end_index_b1])
                    B_3[b1, b2] = np.dot(h_conj[start_index_b1:end_index_b1], conv2[start_index_b1:end_index_b1])
            Summary_data_dict[k] = (A_0, A_1, B_0, B_1, B_2, B_3)
        self.Summary_data_dict = Summary_data_dict

    def SphericalHarmonics22(self,theta, phi, m):
        return np.sqrt(5.0 / ( 64.0 * np.pi )) * ( 1.0 + np.cos( theta ))*( 1.0 + np.cos( theta )) * np.exp(1j * m * phi)
    
    def SphericalHarmonics2minus2(self,theta, phi, m):
        return np.sqrt( 5.0 / ( 64.0 * np.pi ) ) * ( 1.0 - np.cos( theta ))*( 1.0 - np.cos( theta )) * np.exp(1j * m * phi)

    def shifted_waveform(self, Time):
        h_H1 = self.waveform_22_modes(self.parameters, Time)
        dt = self.time[1] - self.time[0]
        
        h22_dict = {}
        for k in self.Detectors_list.keys():
            t_delay = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                t_gps=self.parameters["H1_time"],
            )
            total_shift = (
                t_delay + self.parameters["H1_time"]
                - self.injection_parameters["H1_time"]
                - self.t_delay_injection_dict[k]
            )
            
            shift_indices = int(round(total_shift / dt))
            h22_dict[k] = np.roll(h_H1, shift_indices)
            
        return h22_dict

    def Actual_shifted_waveform(self):
        h_H1 = self.waveform_22_modes(self.parameters, self.time_on_edge["H1"])
        dt = self.time[1]-self.time[0]
        h22_dict = {}
        for k in self.Detectors_list.keys():
            # Time delay and 22 mode
            t_delay = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                t_gps=self.parameters["H1_time"],
            )
            h22_dict[k] = self.waveform_22_modes(
                self.parameters,
                self.Time_array_per_detector[k]
                - (
                    t_delay
                    + self.parameters["H1_time"]
                    - self.injection_parameters["H1_time"]
                ),
            )
        return h22_dict
        
            
    def log_likelihood_ratio2(self):
        """
        Computes Relative Binning log likelihood using summary data and ratio of target 22 mode to fiducial 22 mode r^{22}(t).
        """
        log_like = 0
        # Spherical harmonics
        Y_22 = self.SphericalHarmonics22(
            self.parameters["theta_jn"],
            np.pi / 2 - self.parameters["phase"],
            2,
        )
        Y_2_minus_2 = self.SphericalHarmonics2minus2(
            self.parameters["theta_jn"],
            np.pi / 2 - self.parameters["phase"],
            -2,
        )
        for k in self.Detectors_list.keys():
            # Summary data
            A_0, A_1, B_0, B_1, B_2, B_3 = self.Summary_data_dict[k]

            # Time delay and 22 mode
            t_delay = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                t_gps=self.parameters["H1_time"],
            )

            h22 = self.waveform_22_modes(
                self.parameters,
                self.time_on_edge[k]
                - (
                    t_delay
                    + self.parameters["H1_time"]
                    - self.injection_parameters["H1_time"]
                ),
            )

            # Antenna pattern
            F_plus, F_cross = self.Detectors_list[k].antenna_pattern(
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                polarization=self.parameters["psi"],
                t_gps=self.parameters["H1_time"],
            )
        
            # Waveform ratio
            
            waveform_ratio = h22 / self.h22_fiducial[k][self.bin_edge_index[k]]
            r_0 = (waveform_ratio[1:] + waveform_ratio[:-1]) / 2
            r_1 = (waveform_ratio[1:] - waveform_ratio[:-1]) / self.bin_width[k]
        
            # Inner products
        
            # Inner_product_d_h22 = np.sum(r_0 * self.A_0 + r_1 * self.A_1)
            
            # Perform one fused operation: element-wise multiply and sum over all elements
            Inner_product_d_h22 = np.dot(r_0,A_0) + np.dot(r_1, A_1)
        
            Y_22_Y_2_minus_2_d_h22 = (
                Y_22 * Inner_product_d_h22
                + Y_2_minus_2 * np.conjugate(Inner_product_d_h22)
            )
        
            Inner_product_di_sj = F_plus * np.real(
                Y_22_Y_2_minus_2_d_h22
            ) - F_cross * np.imag(Y_22_Y_2_minus_2_d_h22)
        
            B0_r0 = np.dot(B_0 , r_0)
            B1_r1 = np.dot(B_1 , r_1)
            B1_r0 = np.dot(B_1 , r_0)
        
            # Inner product: h22 with h22
            Inner_product_h22_h22 = np.dot(r_0 , (B0_r0 + B1_r1)) + np.dot(r_1 , B1_r0)
        
            # Precompute conjugated matrix-vector products
            B2_r0 = np.dot(B_2 , r_0)
            B3_r1 = np.dot(B_3 , r_1)
            B3_r0 = np.dot(B_3 , r_0)
        
            # Inner product: h22 with conjugate(h22)
            Inner_product_h22_conj_h22 = (
                np.dot(np.conjugate(r_0) , (B2_r0 + B3_r1))
                + np.dot(np.conjugate(r_1) , B3_r0)
            )
        
            # Inner_product_h22_h22 = r_0 @ (B_0 @ r_0 + B_1 @ r_1) + r_1 @ B_1 @ r_0
            # Inner_product_h22_conj_h22 = np.conjugate(r_0) @ (B_2 @ r_0 + B_3 @ r_1) + np.conjugate(r_1) @ B_3 @ r_0
        
            Inner_product_sum_h22_sum_h22 = (
                Y_22**2 * Inner_product_h22_h22
                + 2
                * Y_22
                * Y_2_minus_2
                * Inner_product_h22_conj_h22  # Check if this is indeed true.
                + Y_2_minus_2**2 * np.conjugate(Inner_product_h22_h22)
            )
        
            Inner_product_sum_h22_conj_sum_h22 = np.conjugate(Y_22) * (
                Y_22 * Inner_product_h22_conj_h22
                + Y_2_minus_2 * np.conjugate(Inner_product_h22_h22)
            ) + Y_2_minus_2 * (
                Y_22 * Inner_product_h22_h22
                + np.conjugate(Y_2_minus_2) * Inner_product_h22_conj_h22
            )
        
            Inner_product_si_sj = (
                0.5
                * (F_plus**2 + F_cross**2)
                * np.real(Inner_product_sum_h22_conj_sum_h22)
                + 0.5
                * (F_plus**2 - F_cross**2)
                * np.real(Inner_product_sum_h22_sum_h22)
                - F_plus
                * F_cross
                * np.imag(
                    Inner_product_sum_h22_sum_h22 + Inner_product_sum_h22_conj_sum_h22
                )
            )
        
            log_like += Inner_product_di_sj - 0.5 * Inner_product_si_sj

        return log_like

    def log_likelihood_ratio3(self):
        """
        Computes Relative Binning log likelihood using summary data and ratio of target 22 mode to fiducial 22 mode r^{22}(t).
        """
        log_like = 0
        for k in self.Detectors_list.keys():
            # Summary data
            A_0, A_1, B_0, B_1, B_2, B_3 = self.Summary_data_dict[k]

            # Time delay and 22 mode
            t_delay = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                t_gps=self.parameters["H1_time"],
            )
            Y_22 = lal.SpinWeightedSphericalHarmonic(
                self.parameters["theta_jn"],
                np.pi / 2 - self.parameters["phase"],
                -2,
                2,
                2,
            )
            Y_2_minus_2 = lal.SpinWeightedSphericalHarmonic(
                self.parameters["theta_jn"],
                np.pi / 2 - self.parameters["phase"],
                -2,
                2,
                -2,
            )
            h22 = self.waveform_22_modes(
                self.parameters,
                self.time_on_edge[k]
                - (
                    t_delay
                    + self.parameters["H1_time"]
                    - self.injection_parameters["H1_time"]
                ),
            )

            # Antenna pattern
            F_plus, F_cross = self.Detectors_list[k].antenna_pattern(
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                polarization=self.parameters["psi"],
                t_gps=self.parameters["H1_time"],
            )
        
            # Waveform ratio
            
            waveform_ratio = h22 / self.h22_fiducial[k][self.bin_edge_index[k]]
            r_0 = (waveform_ratio[1:] + waveform_ratio[:-1]) / 2
            r_1 = (waveform_ratio[1:] - waveform_ratio[:-1]) / self.bin_width[k]
        
            # Inner products
        
            # Inner_product_d_h22 = np.sum(r_0 * self.A_0 + r_1 * self.A_1)
            
            # Perform one fused operation: element-wise multiply and sum over all elements
            Inner_product_d_h22 = np.dot(r_0,A_0) + np.dot(r_1, A_1)
        
            Y_22_Y_2_minus_2_d_h22 = (
                Y_22 * Inner_product_d_h22
                + Y_2_minus_2 * np.conjugate(Inner_product_d_h22)
            )
        
            Inner_product_di_sj = F_plus * np.real(
                Y_22_Y_2_minus_2_d_h22
            ) - F_cross * np.imag(Y_22_Y_2_minus_2_d_h22)
        
            B0_r0 = np.dot(B_0 , r_0)
            B1_r1 = np.dot(B_1 , r_1)
            B1_r0 = np.dot(B_1 , r_0)
        
            # Inner product: h22 with h22
            Inner_product_h22_h22 = np.dot(r_0 , (B0_r0 + B1_r1)) + np.dot(r_1 , B1_r0)
        
            # Precompute conjugated matrix-vector products
            B2_r0 = np.dot(B_2 , r_0)
            B3_r1 = np.dot(B_3 , r_1)
            B3_r0 = np.dot(B_3 , r_0)
        
            # Inner product: h22 with conjugate(h22)
            Inner_product_h22_conj_h22 = (
                np.dot(np.conjugate(r_0) , (B2_r0 + B3_r1))
                + np.dot(np.conjugate(r_1) , B3_r0)
            )
        
            # Inner_product_h22_h22 = r_0 @ (B_0 @ r_0 + B_1 @ r_1) + r_1 @ B_1 @ r_0
            # Inner_product_h22_conj_h22 = np.conjugate(r_0) @ (B_2 @ r_0 + B_3 @ r_1) + np.conjugate(r_1) @ B_3 @ r_0
        
            Inner_product_sum_h22_sum_h22 = (
                Y_22**2 * Inner_product_h22_h22
                + 2
                * Y_22
                * Y_2_minus_2
                * Inner_product_h22_conj_h22  # Check if this is indeed true.
                + Y_2_minus_2**2 * np.conjugate(Inner_product_h22_h22)
            )
        
            Inner_product_sum_h22_conj_sum_h22 = np.conjugate(Y_22) * (
                Y_22 * Inner_product_h22_conj_h22
                + Y_2_minus_2 * np.conjugate(Inner_product_h22_h22)
            ) + Y_2_minus_2 * (
                Y_22 * Inner_product_h22_h22
                + np.conjugate(Y_2_minus_2) * Inner_product_h22_conj_h22
            )
        
            Inner_product_si_sj = (
                0.5
                * (F_plus**2 + F_cross**2)
                * np.real(Inner_product_sum_h22_conj_sum_h22)
                + 0.5
                * (F_plus**2 - F_cross**2)
                * np.real(Inner_product_sum_h22_sum_h22)
                - F_plus
                * F_cross
                * np.imag(
                    Inner_product_sum_h22_sum_h22 + Inner_product_sum_h22_conj_sum_h22
                )
            )
        
            log_like += Inner_product_di_sj - 0.5 * Inner_product_si_sj

        return log_like

    def noise_log_likelihood(self):
        """
        Computes log likelihood for noise.
        """
        if self.noise_log_likelihood_value is None:
            noise_log_like = 0
            for k in self.Detectors_list.keys():
                noise_log_like += -0.5 * self.data_times_C_inv_times_data[k]
            self.noise_log_likelihood_value = noise_log_like
        return self.noise_log_likelihood_value

    def log_likelihood(self):
        """
        Computes log likelihood.
        """
        log_like = self.log_likelihood_ratio() + self.noise_log_likelihood()
        return log_like

    def log_likelihood_ratio(self):
        log_like = 0
        for k in self.Detectors_list.keys():
            t_delay = self.Detectors_list[k].time_delay_from_detector(
                other_detector=self.Detectors_list["H1"],
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                t_gps=self.parameters["H1_time"],
            )
            h = self.waveform(
                self.parameters,
                self.Time_array_per_detector[k]
                - (
                    t_delay
                    + self.parameters["H1_time"]
                    - self.injection_parameters["H1_time"]
                ),
            )

            # Antenna pattern
            F_plus, F_cross = self.Detectors_list[k].antenna_pattern(
                right_ascension=self.parameters["ra"],
                declination=self.parameters["dec"],
                polarization=self.parameters["psi"],
                t_gps=self.parameters["H1_time"],
            )
            log_like += np.dot(self.data_times_C_inv[k], F_plus*np.real(h) + F_cross*(-np.imag(h))) - 0.5 * self.weighted_inner_product_circulant(F_plus*np.real(h) + F_cross*(-np.imag(h)), F_plus*np.real(h) + F_cross*(-np.imag(h)), self.C_inv_row[k])
        return log_like

# %%
with open("/home/neha/Relative-binning-time-domain/ACF_noise_and_covariance_matrix_data/C_inv_row_2_sec.pkl", "rb") as f:
    Inv_cov_Noise_circulant = dill.load(f)

# %%
C_inv_row = Inv_cov_Noise_circulant["C_inv"]
Noise_row = Inv_cov_Noise_circulant["Noise"]

# %%
Noise_zero = {"L1":0,"H1":0,"V1":0}

# %%
fiducial_parameters = priors.sample()
n,epsilon,spacing = 2.0,[0.5,0.5],[1,10,100]
Detectors_list = {"L1":bilby.gw.detector.get_empty_interferometer("L1"),"H1":bilby.gw.detector.get_empty_interferometer("H1"),"V1":bilby.gw.detector.get_empty_interferometer("V1")}
Data_list = {}
m1,m2 = chirp_mass_and_mass_ratio_to_component_masses(fiducial_parameters["chirp_mass"],fiducial_parameters["mass_ratio"])
Time_array = np.arange(-n+0.5,0.5,1/4096.0, dtype = np.float64)
# C_inv_row = {"H1":np.random.uniform(0,1, len(Time_array))*1e43,"L1":np.random.uniform(0,1, len(Time_array))*1e43,"V1":np.random.uniform(0,1, len(Time_array))*1e43}

hp, hc = get_td_waveform(approximant = "IMRPhenomT",
                         mass1 = m1,
                         mass2 = m2,
                         spin1z = fiducial_parameters["chi_1"],
                         spin2z = fiducial_parameters["chi_2"],
                         distance = fiducial_parameters["luminosity_distance"],
                         inclination = fiducial_parameters["theta_jn"],
                         coa_phase = fiducial_parameters["phase"],
                         delta_t = 1.0/4096,
                         f_lower = 10)

time_arr = hp.sample_times.data
h_pycbc = hp.data - 1j*hc.data
print(time_arr)

# %%
# SNR_bilby,SNR_bilby_2,likelihood_bilby = SNR_using_bilby(fiducial_parameters)
# print(SNR_bilby,SNR_bilby_2)
to_h1 = Detector('H1').time_delay_from_earth_center(fiducial_parameters['ra'], fiducial_parameters['dec'], fiducial_parameters['geocent_time'])
fiducial_parameters["H1_time"] = fiducial_parameters["geocent_time"] + to_h1   # New parameter H1_time : arrival time in detector H1
priors["H1_time"] = bilby.core.prior.Uniform(
            fiducial_parameters["H1_time"] - 0.01,
            fiducial_parameters["H1_time"] + 0.01,
            name="H1_time",
            latex_label="$t_{H1}$",
            unit=None,
            boundary=None,
        )
# priors.pop("geocent_time")
# fiducial_parameters.pop("geocent_time")
injection_parameters = fiducial_parameters.copy()

# %%
Detectors_list_2 = {"L1":Detector("L1"),"H1":Detector("H1"),"V1":Detector("V1")}

# %%
Likelihood_obj_H1 = RelativeBinningTimeDomain_H1detectorframe_for_longer_signals_new(Time_array,
                                                                                     Detectors_list_2,
                                                                                     fiducial_parameters,
                                                                                     injection_parameters,
                                                                                     Data_list, 
                                                                                     C_inv_row,
                                                                                     Noise_zero,
                                                                                     {'H1': np.array([0.5, 0.5]), 'L1': np.array([0.5, 0.5]), 'V1': np.array([0.5, 0.5])})
SNR_dict_row_2, Network_SNR_row_2,h_2,data_2,data_C_inv_2 = Likelihood_obj_H1.compute_SNR_TD_and_waveform_data()

# %%
Likelihood_obj_H1.number_of_bins

# %%
# %%timeit

Likelihood_obj_H1.waveform(fiducial_parameters, Likelihood_obj_H1.Time_array_per_detector["H1"])

# %%
# %%timeit
h_base = Likelihood_obj_H1.waveform(fiducial_parameters, Likelihood_obj_H1.Time_array_per_detector["H1"])
h_dict = {}
dt = Time_array[1] - Time_array[0]
for k in Detectors_list_2.keys():
    # Calculate the time delay for the current detector 'k'
    t_delay = Detectors_list_2[k].time_delay_from_detector(
        other_detector=Detectors_list_2["H1"],
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        t_gps=fiducial_parameters["H1_time"],
    )

    total_shift = (t_delay + fiducial_parameters["H1_time"]
                   - fiducial_parameters["H1_time"])
    shift_indices = int(round(total_shift / dt))
    h_dict[k] = np.roll(h_base, shift_indices)

log_like=0
for k in Detectors_list_2.keys():
    h = h_dict[k]
    F_plus, F_cross = Detectors_list_2[k].antenna_pattern(
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        polarization=fiducial_parameters["psi"],
        t_gps=fiducial_parameters["H1_time"],
    )
    log_like += np.dot(Likelihood_obj_H1.data_times_C_inv[k], F_plus*np.real(h) + F_cross*(-np.imag(h))) - 0.5 * Likelihood_obj_H1.weighted_inner_product_circulant(F_plus*np.real(h) + F_cross*(-np.imag(h)), F_plus*np.real(h) + F_cross*(-np.imag(h)), Likelihood_obj_H1.C_inv_row[k])

# %%
# %%timeit

Likelihood_obj_H1.waveform_22_modes(fiducial_parameters, Likelihood_obj_H1.time_on_edge["H1"])

# %%
# %%timeit
h_base = Likelihood_obj_H1.waveform_22_modes(fiducial_parameters, Likelihood_obj_H1.time_on_edge["H1"])
dt = Time_array[1] - Time_array[0]  # Calculate the time step
h22_dict = {}

for k in Detectors_list_2.keys():
    # Calculate the time delay for the current detector 'k'
    t_delay = Detectors_list_2[k].time_delay_from_detector(
        other_detector=Detectors_list_2["H1"],
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        t_gps=fiducial_parameters["H1_time"],
    )

    total_shift = (t_delay + fiducial_parameters["H1_time"]
                   - fiducial_parameters["H1_time"])
    shift_indices = int(round(total_shift / dt))
    h22_dict[k] = np.roll(h_base, shift_indices)

log_like = 0
# Spherical harmonics
Y_22 = Likelihood_obj_H1.SphericalHarmonics22(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    2,
)
Y_2_minus_2 = Likelihood_obj_H1.SphericalHarmonics2minus2(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    -2,
)
for k in Detectors_list_2.keys():
    A_0, A_1, B_0, B_1, B_2, B_3 = Likelihood_obj_H1.Summary_data_dict[k]
    h22 = h22_dict[k]
    # Antenna pattern
    F_plus, F_cross = Detectors_list_2[k].antenna_pattern(
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        polarization=fiducial_parameters["psi"],
        t_gps=fiducial_parameters["H1_time"],
    )

    # Waveform ratio
    
    waveform_ratio = h22 / Likelihood_obj_H1.h22_fiducial[k][Likelihood_obj_H1.bin_edge_index[k]]
    r_0 = (waveform_ratio[1:] + waveform_ratio[:-1]) / 2
    r_1 = (waveform_ratio[1:] - waveform_ratio[:-1]) / Likelihood_obj_H1.bin_width[k]

    # Inner products

    # Inner_product_d_h22 = np.sum(r_0 * self.A_0 + r_1 * self.A_1)
    
    # Perform one fused operation: element-wise multiply and sum over all elements
    Inner_product_d_h22 = np.dot(r_0,A_0) + np.dot(r_1, A_1)

    Y_22_Y_2_minus_2_d_h22 = (
        Y_22 * Inner_product_d_h22
        + Y_2_minus_2 * np.conjugate(Inner_product_d_h22)
    )

    Inner_product_di_sj = F_plus * np.real(
        Y_22_Y_2_minus_2_d_h22
    ) - F_cross * np.imag(Y_22_Y_2_minus_2_d_h22)

    B0_r0 = np.dot(B_0 , r_0)
    B1_r1 = np.dot(B_1 , r_1)
    B1_r0 = np.dot(B_1 , r_0)

    # Inner product: h22 with h22
    Inner_product_h22_h22 = np.dot(r_0 , (B0_r0 + B1_r1)) + np.dot(r_1 , B1_r0)

    # Precompute conjugated matrix-vector products
    B2_r0 = np.dot(B_2 , r_0)
    B3_r1 = np.dot(B_3 , r_1)
    B3_r0 = np.dot(B_3 , r_0)

    # Inner product: h22 with conjugate(h22)
    Inner_product_h22_conj_h22 = (
        np.dot(np.conjugate(r_0) , (B2_r0 + B3_r1))
        + np.dot(np.conjugate(r_1) , B3_r0)
    )

    # Inner_product_h22_h22 = r_0 @ (B_0 @ r_0 + B_1 @ r_1) + r_1 @ B_1 @ r_0
    # Inner_product_h22_conj_h22 = np.conjugate(r_0) @ (B_2 @ r_0 + B_3 @ r_1) + np.conjugate(r_1) @ B_3 @ r_0

    Inner_product_sum_h22_sum_h22 = (
        Y_22**2 * Inner_product_h22_h22
        + 2
        * Y_22
        * Y_2_minus_2
        * Inner_product_h22_conj_h22  # Check if this is indeed true.
        + Y_2_minus_2**2 * np.conjugate(Inner_product_h22_h22)
    )

    Inner_product_sum_h22_conj_sum_h22 = np.conjugate(Y_22) * (
        Y_22 * Inner_product_h22_conj_h22
        + Y_2_minus_2 * np.conjugate(Inner_product_h22_h22)
    ) + Y_2_minus_2 * (
        Y_22 * Inner_product_h22_h22
        + np.conjugate(Y_2_minus_2) * Inner_product_h22_conj_h22
    )

    Inner_product_si_sj = (
        0.5
        * (F_plus**2 + F_cross**2)
        * np.real(Inner_product_sum_h22_conj_sum_h22)
        + 0.5
        * (F_plus**2 - F_cross**2)
        * np.real(Inner_product_sum_h22_sum_h22)
        - F_plus
        * F_cross
        * np.imag(
            Inner_product_sum_h22_sum_h22 + Inner_product_sum_h22_conj_sum_h22
        )
    )

    log_like += Inner_product_di_sj - 0.5 * Inner_product_si_sj

# %%
h_base = Likelihood_obj_H1.waveform_22_modes(fiducial_parameters, Likelihood_obj_H1.time_on_edge["H1"])
dt = Time_array[1] - Time_array[0]  # Calculate the time step
h22_dict = {}

for k in Detectors_list_2.keys():
    # Calculate the time delay for the current detector 'k'
    t_delay = Detectors_list_2[k].time_delay_from_detector(
        other_detector=Detectors_list_2["H1"],
        right_ascension=fiducial_parameters["ra"],
        declination=fiducial_parameters["dec"],
        t_gps=fiducial_parameters["H1_time"],
    )

    total_shift = (t_delay + fiducial_parameters["H1_time"]
                   - fiducial_parameters["H1_time"] - Likelihood_obj_H1.t_delay_injection_dict[k])
    shift_indices = int(round(total_shift / dt))
    h22_dict[k] = np.roll(h_base, shift_indices)

# %%
plt.plot(Likelihood_obj_H1.Time_array_per_detector["H1"], Likelihood_obj_H1.h22_fiducial["H1"])
plt.scatter(Likelihood_obj_H1.time_on_edge["H1"], h22_dict["H1"], color = "red", marker="x")
plt.xlim(-0.1,0.05)

# %%
plt.plot(Likelihood_obj_H1.Time_array_per_detector["L1"], Likelihood_obj_H1.h22_fiducial["L1"])
plt.scatter(Likelihood_obj_H1.time_on_edge["L1"], h22_dict["L1"], color = "red", marker="x")
plt.xlim(-0.1,0.05)

# %%
plt.plot(Likelihood_obj_H1.Time_array_per_detector["V1"], Likelihood_obj_H1.h22_fiducial["V1"])
plt.scatter(Likelihood_obj_H1.time_on_edge["V1"], h22_dict["V1"], color = "red", marker="x")
plt.xlim(-0.1,0.05)

# %%
fig, ax = plt.subplots(3,1,figsize=(15,5))
ax[0].plot(Likelihood_obj_H1.Time_array_per_detector["H1"],Likelihood_obj_H1.h22_fiducial["H1"])
ax[0].scatter(Likelihood_obj_H1.time_on_edge["H1"],h22_dict["H1"], marker="x",color = "red")
ax[0].set_xlim(-0.3,0.6)

ax[1].plot(Likelihood_obj_H1.Time_array_per_detector["L1"],Likelihood_obj_H1.h22_fiducial["L1"])
ax[1].scatter(Likelihood_obj_H1.time_on_edge["L1"],h22_dict["L1"], marker="x",color = "red")
ax[1].set_xlim(-0.3,0.6)

ax[2].plot(Likelihood_obj_H1.Time_array_per_detector["V1"],Likelihood_obj_H1.h22_fiducial["V1"])
ax[2].scatter(Likelihood_obj_H1.time_on_edge["V1"],h22_dict["V1"], marker="x",color = "red")
ax[2].set_xlim(-0.3,0.6)

# %%
Likelihood_obj_H1.h22_fiducial["H1"][Likelihood_obj_H1.bin_edge_index["H1"]] - h22_dict["H1"]

# %%
Likelihood_obj_H1.h22_fiducial["L1"][Likelihood_obj_H1.bin_edge_index["L1"]] - h22_dict["L1"]

# %%
Likelihood_obj_H1.h22_fiducial["V1"][Likelihood_obj_H1.bin_edge_index["V1"]] - h22_dict["V1"]

# %%
pp = priors.sample()
Likelihood_obj_H1.parameters.update(pp)

# %%
# %%timeit

Likelihood_obj_H1.log_likelihood_ratio()

# %%
# %%timeit

Likelihood_obj_H1.log_likelihood_ratio2()

# %%
# %%timeit

Likelihood_obj_H1.log_likelihood_ratio3()

# %%
fig, ax = plt.subplots(3,1,figsize=(20,8))
ax[0].plot(Likelihood_obj_H1.Time_array_per_detector["H1"],Likelihood_obj_H1.waveform_22_modes(pp, Likelihood_obj_H1.Time_array_per_detector["H1"]))
ax[0].plot(Likelihood_obj_H1.Time_array_per_detector["H1"],Likelihood_obj_H1.waveform_22_modes_2(pp, Likelihood_obj_H1.Time_array_per_detector["H1"]),linestyle="dashed",color = "red")
ax[0].set_xlim(-0.3,0.6)

ax[1].plot(Likelihood_obj_H1.Time_array_per_detector["L1"],Likelihood_obj_H1.waveform_22_modes(pp, Likelihood_obj_H1.Time_array_per_detector["L1"]))
ax[1].plot(Likelihood_obj_H1.Time_array_per_detector["L1"],Likelihood_obj_H1.waveform_22_modes_2(pp, Likelihood_obj_H1.Time_array_per_detector["L1"]),linestyle="dashed",color = "red")
ax[1].set_xlim(-0.3,0.6)

ax[2].plot(Likelihood_obj_H1.Time_array_per_detector["V1"],Likelihood_obj_H1.waveform_22_modes(pp, Likelihood_obj_H1.Time_array_per_detector["V1"]))
ax[2].plot(Likelihood_obj_H1.Time_array_per_detector["V1"],Likelihood_obj_H1.waveform_22_modes_2(pp, Likelihood_obj_H1.Time_array_per_detector["V1"]),linestyle="dashed",color = "red")
ax[2].set_xlim(-0.3,0.6)

# %%
# %%timeit

Likelihood_obj_H1.waveform_22_modes(pp, Likelihood_obj_H1.Time_array_per_detector["H1"])

# %%
# %%timeit

Likelihood_obj_H1.waveform_22_modes_2(pp, Likelihood_obj_H1.Time_array_per_detector["H1"])

# %%
# plt.scatter(Likelihood_obj_H1.time_on_edge["H1"], np.abs(Likelihood_obj_H1.h22_fiducial["H1"][Likelihood_obj_H1.bin_edge_index["H1"]] - h["H1"])/(Likelihood_obj_H1.h22_fiducial["H1"][Likelihood_obj_H1.bin_edge_index["H1"]]))

# %%
SNR_dict_row_2, Network_SNR_row_2
# Out:
# ({'L1': 34.80942199585047, 'H1': 36.56405499207999, 'V1': 8.594397554470115},
#  51.21024942795466)

# %%
del_mc = (1.2e-4)*fiducial_parameters["chirp_mass"] ** (8/3) * (10/Network_SNR_row_2)
print(del_mc)
mc_min = fiducial_parameters["chirp_mass"]-del_mc
mc_max = fiducial_parameters["chirp_mass"]+del_mc
priors["chirp_mass"] = bilby.core.prior.Uniform(minimum=mc_min,maximum=mc_max,name="chirp_mass",latex_label="$\\mathcal{M}$")
# Out:
# 1.1070825999569982

# %%
Exact_logl = []
Approx_logl = []
parameters =  injection_parameters.copy()
params = []
Full_params_dict = []
key = 'H1_time'
dt = []
dt2 = []
for i in range(100):
    parameters[key] = priors.sample()[key]
    start_time = time.time()
    Likelihood_obj_H1.parameters.update(parameters)
    Approx_logl.append(Likelihood_obj_H1.log_likelihood_ratio2())
    dt.append(time.time()-start_time)

    start_time = time.time()
    Likelihood_obj_H1.parameters.update(parameters)
    Exact_logl.append(Likelihood_obj_H1.log_likelihood_ratio())
    dt2.append(time.time()-start_time)
    params.append(parameters[key])
    Full_params_dict.append(parameters)

Exact_logl = np.array(Exact_logl)
Approx_logl = np.array(Approx_logl)

# %%
np.sum(np.array(dt)),np.sum(np.array(dt2))
# Out:
# (4.928170919418335, 9.532802104949951)

# %%
fig, ax = plt.subplots(1,2,figsize=(16,6))
ax[0].scatter(params,Exact_logl,alpha=0.6,color = "black",label = "Exact Likelihood")
ax[0].axvline(fiducial_parameters[key])
ax[0].scatter(params,Approx_logl,alpha=0.4,marker=".",color = "red",label = "Relative Binning")
ax[0].legend()
ax[0].set_xlabel(key)
ax[0].set_ylabel("Log Likelihood")

ax[1].scatter(params,np.abs((Exact_logl-Approx_logl)/(Exact_logl)),marker=".",color = "yellow")
ax[1].set_xlabel(key)
ax[1].set_ylabel("Relative difference")
ax[1].set_yscale("log")

# %%
np.sum(np.array(dt2))/100 * 1000

# %%
0.1 * 1000

# %%
# %%timeit

Y_22 = lal.SpinWeightedSphericalHarmonic(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    -2,
    2,
    2,
)
Y_2_minus_2 = lal.SpinWeightedSphericalHarmonic(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    -2,
    2,
    -2,
)

# %%
Y_22 = lal.SpinWeightedSphericalHarmonic(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    -2,
    2,
    2,
)
Y_2_minus_2 = lal.SpinWeightedSphericalHarmonic(
    fiducial_parameters["theta_jn"],
    np.pi / 2 - fiducial_parameters["phase"],
    -2,
    2,
    -2,
)

Y_22, Y_2_minus_2
# Out:
# ((0.02379386260362366+0.0067167708171490415j),
#  (0.3904842663544346-0.11022982558560644j))

# %%
# %%timeit
SphericalHarmonics22(fiducial_parameters["theta_jn"], np.pi/2 - fiducial_parameters["phase"],2), SphericalHarmonics2minus2(fiducial_parameters["theta_jn"], np.pi/2 - fiducial_parameters["phase"],-2)
# Out:
# 7.78 μs ± 71.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
SphericalHarmonics22(fiducial_parameters["theta_jn"], np.pi/2 - fiducial_parameters["phase"],2), SphericalHarmonics2minus2(fiducial_parameters["theta_jn"], np.pi/2 - fiducial_parameters["phase"],-2)
# Out:
# ((0.02379386260362366+0.0067167708171490415j),
#  (0.3904842663544346-0.11022982558560644j))
